# %% [markdown]
# <img src="https://github.com/danielscarvalho/data/blob/master/img/FIAP-logo.png?raw=True" style="float:right;" width="200px">
#
# # DATA SCIENCE & STATISTICAL COMPUTING [》](https://www.fiap.com.br/)
#
# ## Dataframe & Python
#
# ### LAP Parte 1: “10 minutes to pandas"
#
# https://pandas.pydata.org/docs/user_guide/10min.html

# %% [markdown]
# Sugestão: Colocar a página do Cookbook lado a lado com este notebook para realizar as operações.

# %%
import numpy as np
import pandas as pd

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit              : a671b5a8bf5dd13fb19f0e88edc679bc9e15c673
# python              : 3.11.5.final.0
# python-bits         : 64
# OS                  : Linux
# OS-release          : 6.5.0-17-generic
# Version             : #17~22.04.1-Ubuntu SMP PREEMPT_DYNAMIC Tue Jan 16 14:32:32 UTC 2
# machine             : x86_64
# processor           : x86_64
# byteorder           : little
# LC_ALL              : None
# LANG                : pt_BR.UTF-8
# LOCALE              : pt_BR.UTF-8
#
# pandas              : 2.1.4
# numpy               : 1.26.3
# pytz                : 2023.3.post1
# dateutil            : 2.8.2
# setuptools          : 68.0.0
# pip                 : 23.2.1
# Cython              : None
# pytest              : 7.4.0
# hypothesis          : None
# sphinx              : 5.0.2
# blosc               : None
# feather             : None
# xlsxwriter          : None
# lxml.etree          : 4.9.3
# html5lib            : None
# pymysql             : None
# psycopg2            : None
# jinja2              : 3.1.3
# IPython             : 8.20.0
# pandas_datareader   : None
# bs4                 : 4.12.2
# bottleneck          : 1.3.5
# dataframe-api-compat: None
# fastparquet         : None
# fsspec              : 2023.10.0
# gcsfs               : None
# matplotlib          : 3.8.0
# numba               : 0.58.1
# numexpr             : 2.8.7
# odfpy               : None
# openpyxl            : 3.0.10
# pandas_gbq          : None
# pyarrow             : 11.0.0
# pyreadstat          : None
# pyxlsb              : None
# s3fs                : 2023.10.0
# scipy               : 1.11.4
# sqlalchemy          : 2.0.25
# tables              : 3.9.2
# tabulate            : 0.9.0
# xarray              : 2023.6.0
# xlrd                : None
# zstandard           : 0.19.0
# tzdata              : 2023.3
# qtpy                : 2.4.1
# pyqt5               : None

# %% [markdown]
# ### Object creation

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.549298 -0.065658 -1.625809  0.233913
# 2013-01-02 -0.659145  1.952570  0.021570  1.987866
# 2013-01-03 -1.570219  0.632678 -1.165341  0.376726
# 2013-01-04  1.061380 -0.324285 -0.543498  1.007013
# 2013-01-05 -0.335973 -1.228700  1.105375 -0.583322
# 2013-01-06 -0.392811  1.158786  0.599372 -1.597051

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# ### Viewing data

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -1.549298 -0.065658 -1.625809  0.233913
# 2013-01-02 -0.659145  1.952570  0.021570  1.987866
# 2013-01-03 -1.570219  0.632678 -1.165341  0.376726
# 2013-01-04  1.061380 -0.324285 -0.543498  1.007013
# 2013-01-05 -0.335973 -1.228700  1.105375 -0.583322

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04  1.061380 -0.324285 -0.543498  1.007013
# 2013-01-05 -0.335973 -1.228700  1.105375 -0.583322
# 2013-01-06 -0.392811  1.158786  0.599372 -1.597051

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[-1.54929753, -0.06565762, -1.62580891,  0.23391342],
#        [-0.65914475,  1.95256972,  0.0215698 ,  1.98786593],
#        [-1.57021883,  0.63267786, -1.16534085,  0.37672594],
#        [ 1.0613797 , -0.32428525, -0.54349762,  1.00701261],
#        [-0.33597345, -1.22869998,  1.10537483, -0.58332219],
#        [-0.39281056,  1.15878616,  0.59937232, -1.59705061]])

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.574344  0.354232 -0.268055  0.237524
# std    0.971067  1.133304  1.043754  1.242148
# min   -1.570219 -1.228700 -1.625809 -1.597051
# 25%   -1.326759 -0.259628 -1.009880 -0.379013
# 50%   -0.525978  0.283510 -0.260964  0.305320
# 75%   -0.350183  1.027259  0.454922  0.849441
# max    1.061380  1.952570  1.105375  1.987866

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -1.549298   -0.659145   -1.570219    1.061380   -0.335973   -0.392811
# B   -0.065658    1.952570    0.632678   -0.324285   -1.228700    1.158786
# C   -1.625809    0.021570   -1.165341   -0.543498    1.105375    0.599372
# D    0.233913    1.987866    0.376726    1.007013   -0.583322   -1.597051

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.233913 -1.625809 -0.065658 -1.549298
# 2013-01-02  1.987866  0.021570  1.952570 -0.659145
# 2013-01-03  0.376726 -1.165341  0.632678 -1.570219
# 2013-01-04  1.007013 -0.543498 -0.324285  1.061380
# 2013-01-05 -0.583322  1.105375 -1.228700 -0.335973
# 2013-01-06 -1.597051  0.599372  1.158786 -0.392811

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-01-05 -0.335973 -1.228700  1.105375 -0.583322
# 2013-01-04  1.061380 -0.324285 -0.543498  1.007013
# 2013-01-01 -1.549298 -0.065658 -1.625809  0.233913
# 2013-01-03 -1.570219  0.632678 -1.165341  0.376726
# 2013-01-06 -0.392811  1.158786  0.599372 -1.597051
# 2013-01-02 -0.659145  1.952570  0.021570  1.987866

# %% [markdown]
# ## Selection
# ### Getitem ([ ])

# %%
df["A"]
# Out:
# 2013-01-01   -1.549298
# 2013-01-02   -0.659145
# 2013-01-03   -1.570219
# 2013-01-04    1.061380
# 2013-01-05   -0.335973
# 2013-01-06   -0.392811
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -1.549298 -0.065658 -1.625809  0.233913
# 2013-01-02 -0.659145  1.952570  0.021570  1.987866
# 2013-01-03 -1.570219  0.632678 -1.165341  0.376726

# %%
df[1:-1]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.072778  0.028151 -0.268992 -0.132020
# 2013-01-03 -0.174829 -0.358285  0.719643 -1.918939
# 2013-01-04 -0.332890 -0.830492 -0.775805 -0.112785
# 2013-01-05  0.003932 -0.376470 -0.311179 -0.815550

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.350970  0.059306 -1.157924 -2.327499
# 2013-01-02 -0.072778  0.028151 -0.268992 -0.132020
# 2013-01-03 -0.174829 -0.358285  0.719643 -1.918939
# 2013-01-04 -0.332890 -0.830492 -0.775805 -0.112785
# 2013-01-05  0.003932 -0.376470 -0.311179 -0.815550
# 2013-01-06 -0.884597 -1.753172 -1.663713  1.216495

# %%
df["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.072778  0.028151 -0.268992 -0.132020
# 2013-01-03 -0.174829 -0.358285  0.719643 -1.918939
# 2013-01-04 -0.332890 -0.830492 -0.775805 -0.112785

# %% [markdown]
# ## Selection by label

# %%
df.loc[dates[0]]
# Out:
# A   -1.549298
# B   -0.065658
# C   -1.625809
# D    0.233913
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01 -1.549298 -0.065658
# 2013-01-02 -0.659145  1.952570
# 2013-01-03 -1.570219  0.632678
# 2013-01-04  1.061380 -0.324285
# 2013-01-05 -0.335973 -1.228700
# 2013-01-06 -0.392811  1.158786

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02 -0.659145  1.952570
# 2013-01-03 -1.570219  0.632678
# 2013-01-04  1.061380 -0.324285

# %%
df.loc[dates[0], "A"]
# Out:
# -1.549297528561404

# %%
df.at[dates[0], "A"]
# Out:
# -1.549297528561404

# %% [markdown]
# ## Selection by position

# %%
df.iloc[3]
# Out:
# A    1.061380
# B   -0.324285
# C   -0.543498
# D    1.007013
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04  1.061380 -0.324285
# 2013-01-05 -0.335973 -1.228700

# %%
df.iloc[[1,2,3], [0,2]]
# Out:
#                    A         C
# 2013-01-02 -0.659145  0.021570
# 2013-01-03 -1.570219 -1.165341
# 2013-01-04  1.061380 -0.543498

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.659145  1.952570  0.021570  1.987866
# 2013-01-03 -1.570219  0.632678 -1.165341  0.376726

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01 -0.065658 -1.625809
# 2013-01-02  1.952570  0.021570
# 2013-01-03  0.632678 -1.165341
# 2013-01-04 -0.324285 -0.543498
# 2013-01-05 -1.228700  1.105375
# 2013-01-06  1.158786  0.599372

# %%
df.iloc[1,1]
# Out:
# 1.952569717271098

# %%
df.iat[1,1]
# Out:
# 1.952569717271098

# %% [markdown]
# ## Boolean indexing

# %%
df[df["A"] > 0]
# Out:
#                   A         B         C         D
# 2013-01-04  1.06138 -0.324285 -0.543498  1.007013

# %%
df[df > 0]
# Out:
#                   A         B         C         D
# 2013-01-01      NaN       NaN       NaN  0.233913
# 2013-01-02      NaN  1.952570  0.021570  1.987866
# 2013-01-03      NaN  0.632678       NaN  0.376726
# 2013-01-04  1.06138       NaN       NaN  1.007013
# 2013-01-05      NaN       NaN  1.105375       NaN
# 2013-01-06      NaN  1.158786  0.599372       NaN

# %%
df2 = df.copy()

df2["E"] = ["one", "one", "two", "three", "four", "three"]

df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -1.549298 -0.065658 -1.625809  0.233913    one
# 2013-01-02 -0.659145  1.952570  0.021570  1.987866    one
# 2013-01-03 -1.570219  0.632678 -1.165341  0.376726    two
# 2013-01-04  1.061380 -0.324285 -0.543498  1.007013  three
# 2013-01-05 -0.335973 -1.228700  1.105375 -0.583322   four
# 2013-01-06 -0.392811  1.158786  0.599372 -1.597051  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -1.570219  0.632678 -1.165341  0.376726   two
# 2013-01-05 -0.335973 -1.228700  1.105375 -0.583322  four

# %% [markdown]
# ## Setting

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))

s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df.at[dates[0], "A"] = 0

df.iat[0, 1] = 0

df.loc[:, "D"] = np.array([5] * len(df))

df
# Out:
#                    A         B         C    D
# 2013-01-01  0.000000  0.000000 -1.625809  5.0
# 2013-01-02 -0.659145  1.952570  0.021570  5.0
# 2013-01-03 -1.570219  0.632678 -1.165341  5.0
# 2013-01-04  1.061380 -0.324285 -0.543498  5.0
# 2013-01-05 -0.335973 -1.228700  1.105375  5.0
# 2013-01-06 -0.392811  1.158786  0.599372  5.0

# %%
df2 = df.copy()

df2[df2 > 0] = -df2

df2
# Out:
#                    A         B         C    D
# 2013-01-01  0.000000  0.000000 -1.625809 -5.0
# 2013-01-02 -0.659145 -1.952570 -0.021570 -5.0
# 2013-01-03 -1.570219 -0.632678 -1.165341 -5.0
# 2013-01-04 -1.061380 -0.324285 -0.543498 -5.0
# 2013-01-05 -0.335973 -1.228700 -1.105375 -5.0
# 2013-01-06 -0.392811 -1.158786 -0.599372 -5.0

# %% [markdown]
# ## Missing data

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])

df1.loc[dates[0] : dates[1], "E"] = 1

df1
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.000000  0.000000 -1.625809  5.0  1.0
# 2013-01-02 -0.659145  1.952570  0.021570  5.0  1.0
# 2013-01-03 -1.570219  0.632678 -1.165341  5.0  NaN
# 2013-01-04  1.061380 -0.324285 -0.543498  5.0  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A        B         C    D    E
# 2013-01-01  0.000000  0.00000 -1.625809  5.0  1.0
# 2013-01-02 -0.659145  1.95257  0.021570  5.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.000000  0.000000 -1.625809  5.0  1.0
# 2013-01-02 -0.659145  1.952570  0.021570  5.0  1.0
# 2013-01-03 -1.570219  0.632678 -1.165341  5.0  5.0
# 2013-01-04  1.061380 -0.324285 -0.543498  5.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      E
# 2013-01-01  False  False  False  False  False
# 2013-01-02  False  False  False  False  False
# 2013-01-03  False  False  False  False   True
# 2013-01-04  False  False  False  False   True

# %% [markdown]
# ## Operations

# %%
df.mean()
# Out:
# A   -0.316128
# B    0.365175
# C   -0.268055
# D    5.000000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    0.843548
# 2013-01-02    1.578749
# 2013-01-03    0.724280
# 2013-01-04    1.298399
# 2013-01-05    1.135175
# 2013-01-06    1.591337
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)

s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis="index")
# Out:
#                    A         B         C    D
# 2013-01-01       NaN       NaN       NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN
# 2013-01-03 -2.570219 -0.367322 -2.165341  4.0
# 2013-01-04 -1.938620 -3.324285 -3.543498  2.0
# 2013-01-05 -5.335973 -6.228700 -3.894625  0.0
# 2013-01-06       NaN       NaN       NaN  NaN

# %% [markdown]
# ## User defined functions

# %%
df.agg(lambda x: np.mean(x) * 5.6)
# Out:
# A    -1.770317
# B     2.044979
# C    -1.501108
# D    28.000000
# dtype: float64

# %%
df.transform(lambda x: x * 101.2)
# Out:
#                      A           B           C      D
# 2013-01-01    0.000000    0.000000 -164.531862  506.0
# 2013-01-02  -66.705449  197.600055    2.182864  506.0
# 2013-01-03 -158.906145   64.026999 -117.932494  506.0
# 2013-01-04  107.411625  -32.817668  -55.001959  506.0
# 2013-01-05  -34.000513 -124.344438  111.863933  506.0
# 2013-01-06  -39.752429  117.269160   60.656479  506.0

# %% [markdown]
# ## Value Counts

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

s
# Out:
# 0    5
# 1    6
# 2    2
# 3    6
# 4    6
# 5    3
# 6    0
# 7    3
# 8    1
# 9    0
# dtype: int64

# %%
s.value_counts()
# Out:
# 6    3
# 3    2
# 0    2
# 5    1
# 2    1
# 1    1
# Name: count, dtype: int64

# %% [markdown]
# ## String Methods

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %% [markdown]
# ## Merge
# ## Concat

# %%
df = pd.DataFrame(np.random.randn(10, 4))

df
# Out:
#           0         1         2         3
# 0  0.373528  0.560808 -1.241137 -1.309502
# 1  0.685410  0.884971  0.964545 -1.385593
# 2  1.017394 -0.437949  1.327233  0.171179
# 3 -1.459665 -0.130699  0.059402 -0.563926
# 4  0.020613 -0.494173  0.701726 -0.293002
# 5  1.556359 -0.500160 -1.009769  0.023611
# 6  0.509662 -0.390677 -0.673991 -0.535301
# 7 -0.172229 -0.868237 -0.266628 -0.600323
# 8 -0.793043 -0.968419  0.579943  0.309779
# 9 -0.183036 -0.954824 -2.371807  0.091830

# %%
pieces = [df[:3], df[3:7], df[7:]]

pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.373528  0.560808 -1.241137 -1.309502
# 1  0.685410  0.884971  0.964545 -1.385593
# 2  1.017394 -0.437949  1.327233  0.171179
# 3 -1.459665 -0.130699  0.059402 -0.563926
# 4  0.020613 -0.494173  0.701726 -0.293002
# 5  1.556359 -0.500160 -1.009769  0.023611
# 6  0.509662 -0.390677 -0.673991 -0.535301
# 7 -0.172229 -0.868237 -0.266628 -0.600323
# 8 -0.793043 -0.968419  0.579943  0.309779
# 9 -0.183036 -0.954824 -2.371807  0.091830

# %% [markdown]
# ## Join

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})

right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})

right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
# ## Grouping

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],

        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],

        "C": np.random.randn(8),

        "D": np.random.randn(8),
    }
)

df
# Out:
#      A      B         C         D
# 0  foo    one  0.645387 -1.449370
# 1  bar    one  2.255108  1.050946
# 2  foo    two  0.865152  0.249200
# 3  bar  three -1.012067 -1.379095
# 4  foo    two  0.716248  1.008251
# 5  bar    two  0.949422 -0.144235
# 6  foo    one  1.458931  1.299209
# 7  foo  three  0.658602  2.129805

# %%
df.groupby("A")[["C", "D"]].sum()
# Out:
#             C         D
# A
# bar  2.192463 -0.472384
# foo  4.344320  3.237096

# %%
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one    2.255108  1.050946
#     three -1.012067 -1.379095
#     two    0.949422 -0.144235
# foo one    2.104318 -0.150160
#     three  0.658602  2.129805
#     two    1.581400  1.257452

# %% [markdown]
# ## Reshaping

# %%
arrays = [
   ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],

   ["one", "two", "one", "two", "one", "two", "one", "two"],
]

index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])

df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])

df2 = df[:4]

df2
# Out:
#                      A         B
# first second
# bar   one     0.024783 -0.421542
#       two     0.898817 -0.530158
# baz   one     1.668490 -1.308362
#       two    -0.198107  0.177739

# %%
stacked = df2.stack()

stacked
# Out:
# first  second
# bar    one     A   -0.113791
#                B    0.198037
#        two     A    1.969013
#                B   -0.854878
# baz    one     A    0.247289
#                B   -0.821607
#        two     A    0.317948
#                B    1.124959
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.113791  0.198037
#       two     1.969013 -0.854878
# baz   one     0.247289 -0.821607
#       two     0.317948  1.124959

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -0.113791  1.969013
#       B  0.198037 -0.854878
# baz   A  0.247289  0.317948
#       B -0.821607  1.124959

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -0.113791  0.247289
#        B  0.198037 -0.821607
# two    A  1.969013  0.317948
#        B -0.854878  1.124959

# %% [markdown]
# ## Pivot tables

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,

        "B": ["A", "B", "C"] * 4,

        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,

        "D": np.random.randn(12),

        "E": np.random.randn(12),
    }
)

df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.525847  0.312215
# 1     one  B  foo  0.598240  0.582245
# 2     two  C  foo  1.339896  1.279449
# 3   three  A  bar -0.916461 -2.258043
# 4     one  B  bar -0.370745  0.254329
# 5     one  C  bar  0.824424 -0.132278
# 6     two  A  foo -1.070993 -0.156846
# 7   three  B  foo  1.131961 -1.408859
# 8     one  C  foo  0.475454  2.361334
# 9     one  A  bar -0.777877 -0.134073
# 10    two  B  bar -0.292812 -2.651463
# 11  three  C  bar  1.506263  0.175497

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A -0.777877  0.525847
#       B -0.370745  0.598240
#       C  0.824424  0.475454
# three A -0.916461       NaN
#       B       NaN  1.131961
#       C  1.506263       NaN
# two   A       NaN -1.070993
#       B -0.292812       NaN
#       C       NaN  1.339896

# %% [markdown]
# ## Time series

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="s")

ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

ts.resample("5Min").sum()
# Out:
# 2012-01-01    25232
# Freq: 5T, dtype: int64

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")

ts = pd.Series(np.random.randn(len(rng)), rng)

ts
# Out:
# 2012-03-06   -1.075487
# 2012-03-07   -1.809574
# 2012-03-08    2.107787
# 2012-03-09   -0.674625
# 2012-03-10   -1.427206
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")

ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -1.075487
# 2012-03-07 00:00:00+00:00   -1.809574
# 2012-03-08 00:00:00+00:00    2.107787
# 2012-03-09 00:00:00+00:00   -0.674625
# 2012-03-10 00:00:00+00:00   -1.427206
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00   -1.075487
# 2012-03-06 19:00:00-05:00   -1.809574
# 2012-03-07 19:00:00-05:00    2.107787
# 2012-03-08 19:00:00-05:00   -0.674625
# 2012-03-09 19:00:00-05:00   -1.427206
# Freq: D, dtype: float64

# %%
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
rng + pd.offsets.BusinessDay(5)
# Out:
# DatetimeIndex(['2012-03-13', '2012-03-14', '2012-03-15', '2012-03-16',
#                '2012-03-16'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## Categoricals

# %%
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

df["grade"] = df["raw_grade"].astype("category")

df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
new_categories = ["very good", "good", "very bad"]

df["grade"] = df["grade"].cat.rename_categories(new_categories)

# %%
df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)

df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade", observed=False).size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
# Plotting

# %%
import matplotlib.pyplot as plt

plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

ts = ts.cumsum()

ts.plot();

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)

df = df.cumsum()

plt.figure();

df.plot();

plt.legend(loc='best');

# %% [markdown]
# ## CSV

# %%
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))

df.to_csv("foo.csv")

pd.read_csv("foo.csv")
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  4  4  2  4  1
# 1           1  3  3  2  4  3
# 2           2  3  4  0  1  1
# 3           3  2  1  1  3  0
# 4           4  2  4  4  2  3
# 5           5  3  2  2  0  0
# 6           6  0  4  2  3  3
# 7           7  4  1  0  2  4
# 8           8  3  0  4  2  4
# 9           9  0  1  3  4  1

# %% [markdown]
# ## Parquet

# %%
df.to_parquet("foo.parquet")

pd.read_parquet("foo.parquet")
# Out:
#    0  1  2  3  4
# 0  4  4  2  4  1
# 1  3  3  2  4  3
# 2  3  4  0  1  1
# 3  2  1  1  3  0
# 4  2  4  4  2  3
# 5  3  2  2  0  0
# 6  0  4  2  3  3
# 7  4  1  0  2  4
# 8  3  0  4  2  4
# 9  0  1  3  4  1

# %% [markdown]
# ## Excel

# %%
df.to_excel("foo.xlsx", sheet_name="Sheet1")

pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"])
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  4  4  2  4  1
# 1           1  3  3  2  4  3
# 2           2  3  4  0  1  1
# 3           3  2  1  1  3  0
# 4           4  2  4  4  2  3
# 5           5  3  2  2  0  0
# 6           6  0  4  2  3  3
# 7           7  4  1  0  2  4
# 8           8  3  0  4  2  4
# 9           9  0  1  3  4  1
